# %%
from qiskit.transpiler import CouplingMap


def create_Y(n) -> CouplingMap:
    """Create a Y-shaped coupling map with n qubits."""
    if not n % 2 == 0:
        raise ValueError("n must be odd for a Y-shaped coupling map.")
    result = CouplingMap().from_line(n - 1)
    result.add_physical_qubit(n - 1)
    result.add_edge(n - 1, n // 2)
    return result


def create_T(n) -> CouplingMap:
    """Create a T-shaped coupling map with n qubits."""
    result = CouplingMap().from_line(n - 1)
    result.add_physical_qubit(n - 1)
    result.add_edge(n - 1, n - 3)
    return result


coupling_map_list = [
    *[CouplingMap.from_line(n) for n in range(4, 11)],
    CouplingMap.from_ring(12),
    *[create_Y(2 * n) for n in range(2, 6)],
    *[create_T(n) for n in range(5, 11)],
    CouplingMap(
        [
            [0, 1],
            [1, 0],
            [1, 2],
            [1, 4],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 5],
            [4, 1],
            [4, 7],
            [5, 3],
            [5, 8],
            [6, 7],
            [7, 4],
            [7, 6],
            [7, 10],
            [8, 5],
            [8, 9],
            [8, 11],
            [9, 8],
            [10, 7],
            [10, 12],
            [11, 8],
            [11, 14],
            [12, 10],
            [12, 13],
            [12, 15],
            [13, 12],
            [13, 14],
            [14, 11],
            [14, 13],
            [14, 16],
            [15, 12],
            [15, 18],
            [16, 14],
            [16, 19],
            [17, 18],
            [18, 15],
            [18, 17],
            [18, 21],
            [19, 16],
            [19, 20],
            [19, 22],
            [20, 19],
            [21, 18],
            [21, 23],
            [22, 19],
            [22, 25],
            [23, 21],
            [23, 24],
            [24, 23],
            [24, 25],
            [25, 22],
            [25, 24],
            [25, 26],
            [26, 25],
        ]
    ),
    CouplingMap(
        [
            [0, 1],
            [1, 0],
            [1, 2],
            [1, 4],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 5],
            [3, 30],
            [4, 1],
            [4, 7],
            [5, 3],
            [5, 8],
            [6, 7],
            [7, 4],
            [7, 6],
            [7, 10],
            [8, 5],
            [8, 9],
            [8, 11],
            [9, 8],
            [10, 7],
            [10, 12],
            [11, 8],
            [11, 14],
            [12, 10],
            [12, 13],
            [12, 15],
            [13, 12],
            [13, 14],
            [14, 11],
            [14, 13],
            [14, 16],
            [15, 12],
            [15, 18],
            [16, 14],
            [16, 19],
            [17, 18],
            [18, 15],
            [18, 17],
            [18, 21],
            [19, 16],
            [19, 20],
            [19, 22],
            [20, 19],
            [21, 18],
            [21, 23],
            [22, 19],
            [22, 25],
            [23, 21],
            [23, 24],
            [23, 27],
            [24, 23],
            [24, 25],
            [25, 22],
            [25, 24],
            [25, 26],
            [26, 25],
            [27, 23],
            [27, 28],
            [28, 27],
            [28, 29],
            [29, 28],
            [30, 3],
            [30, 31],
            [31, 30],
            [31, 32],
            [32, 31],
        ]
    ),
    CouplingMap(
        [
            [0, 1],
            [0, 10],
            [1, 0],
            [1, 2],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 4],
            [4, 3],
            [4, 5],
            [4, 11],
            [5, 4],
            [5, 6],
            [6, 5],
            [6, 7],
            [7, 6],
            [7, 8],
            [8, 7],
            [8, 9],
            [115, 114],
            [115, 116],
            [116, 110],
            [116, 115],
            [116, 117],
            [117, 116],
            [117, 118],
            [118, 117],
            [118, 119],
            [118, 130],
            [119, 118],
            [119, 120],
            [120, 111],
            [120, 119],
            [120, 121],
            [121, 120],
            [121, 122],
            [122, 121],
            [122, 123],
            [122, 131],
            [123, 122],
            [123, 124],
            [124, 112],
            [124, 123],
            [124, 125],
            [125, 124],
            [125, 126],
            [126, 125],
            [126, 127],
            [126, 132],
            [127, 126],
            [127, 128],
            [128, 113],
            [128, 127],
            [129, 114],
            [130, 118],
            [131, 122],
            [132, 126],
        ]
    ),
]

# %%
import random

from qiskit.circuit import Qubit
from qiskit.circuit.random import random_circuit
from qiskit.transpiler.layout import Layout
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import (
    ApplyLayout,
    EnlargeWithAncilla,
    FullAncillaAllocation,
    TrivialLayout,
    SetLayout,
    SabreSwap
)
from qiskit.converters import circuit_to_dag
from qiskit_ibm_transpiler.ai.routing import AIRouting

coupling_map = random.choice(coupling_map_list)
circuit = random_circuit(
                num_qubits=len(coupling_map.physical_qubits),
                depth=4,
                max_operands=2,
                measure=False,
                num_operand_distribution={1: 0, 2: 1},
            )
apply_ancilla_pass_manager = PassManager(
            [
                TrivialLayout(coupling_map),
                FullAncillaAllocation(coupling_map),
                EnlargeWithAncilla(),
                ApplyLayout(),
            ]
        )
layout_circuit = apply_ancilla_pass_manager.run(circuit)
layout_dag = circuit_to_dag(layout_circuit)
temp_layout = Layout(
    {
        dagInNode.wire: pq._index
        for pq, dagInNode in layout_dag.input_map.items()
        if isinstance(pq, Qubit)
    }
)
layout_dict = temp_layout.get_virtual_bits()
values = list(layout_dict.values())
keys = list(layout_dict.keys())
random.shuffle(values)
layout = Layout(dict(zip(keys, values)))
apply_layout_pass_manager = PassManager(
    [
        SetLayout(layout),
        ApplyLayout(),
        AIRouting(coupling_map, seed=42, max_iterations=1000, verbose=False, local_mode=True),
    ]
)
result_circuit = apply_layout_pass_manager.run(layout_circuit)
apply_sabre_pass_manager = PassManager(
    [
        SetLayout(layout),
        ApplyLayout(),
        SabreSwap(coupling_map, trials=10),
    ]
)
result_circuit_sabre = apply_sabre_pass_manager.run(layout_circuit)

# Figure out the number of gates added by the sabre swap
print("Number of gates in the original circuit:")
print(circuit.count_ops())
print("Number of gates in the transpiled circuit:")
print(result_circuit.count_ops())
print("Number of gates in the sabre swapped circuit:")
print(result_circuit_sabre.count_ops())
print("Number of gates added by the ai sabre swap:")
print(result_circuit.size() - circuit.size(), len(list(circuit_to_dag(result_circuit).layers())) - len(list(circuit_to_dag(circuit).layers())))
print("Number of gates added by the sabre swap (sabre swapped circuit):")
print(result_circuit_sabre.size() - circuit.size(), len(list(circuit_to_dag(result_circuit_sabre).layers())) - len(list(circuit_to_dag(circuit).layers())))
# Out:
# Number of gates in the original circuit:
# OrderedDict({'cp': 7, 'rzx': 6, 'cx': 6, 'cy': 5, 'crx': 4, 'ch': 4, 'cz': 3, 'cu1': 3, 'crz': 3, 'ryy': 3, 'xx_plus_yy': 3, 'cry': 2, 'iswap': 2, 'csx': 2, 'swap': 2, 'cu': 2, 'cu3': 2, 'cs': 1, 'rxx': 1, 'csdg': 1, 'ecr': 1, 'xx_minus_yy': 1})
# Number of gates in the transpiled circuit:
# OrderedDict({'swap': 87, 'cp': 7, 'rzx': 6, 'cx': 6, 'cy': 5, 'ch': 4, 'crx': 4, 'cu1': 3, 'ryy': 3, 'cz': 3, 'crz': 3, 'xx_plus_yy': 3, 'cry': 2, 'cu': 2, 'iswap': 2, 'csx': 2, 'cu3': 2, 'cs': 1, 'csdg': 1, 'ecr': 1, 'rxx': 1, 'xx_minus_yy': 1})
# Number of gates in the sabre swapped circuit:
# OrderedDict({'swap': 198, 'cp': 7, 'rzx': 6, 'cx': 6, 'cy': 5, 'ch': 4, 'crx': 4, 'crz': 3, 'cz': 3, 'ryy': 3, 'cu1': 3, 'xx_plus_yy': 3, 'cry': 2, 'cu': 2, 'iswap': 2, 'csx': 2, 'cu3': 2, 'rxx': 1, 'cs': 1, 'csdg': 1, 'xx_minus_yy': 1, 'ecr': 1})
# Number of gates added by the ai sabre swap:
# 85 17
# Number of gates added by the sabre swap (sabre swapped circuit):
# 196 55

# %%
from typing import Any, SupportsFloat
from copy import deepcopy
import gymnasium as gym
import numpy as np
import random

from qiskit import QuantumCircuit
from qiskit.circuit import Qubit
from qiskit.circuit.library.standard_gates import SwapGate
from qiskit.transpiler import CouplingMap, PassManager
from qiskit.transpiler.passes import (
    TrivialLayout,
    ApplyLayout,
    EnlargeWithAncilla,
    FullAncillaAllocation,
)
from qiskit.transpiler.layout import Layout
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit.dagcircuit import DAGCircuit
from collections import deque


# pick optimum edge to swap
class SABRETestEnv(gym.Env):
    def __init__(
        self,
        S_a: int = 8,
        H: int = 4,
        start_level: int = 1,
        max_window_size: int = 100,
        random_layout: bool = True,
        circuit: QuantumCircuit | None = None,
        coupling_map: CouplingMap | None = None,
    ) -> None:
        self._S_a = S_a
        self._H = H
        self._level = start_level
        self._swap_singleton = SwapGate()
        self._reset_failed = 0
        self._result_deque = deque(maxlen=max_window_size)
        self._random_layout = random_layout
        if circuit is None:
            raise ValueError("A circuit must be provided.")
        if coupling_map is None:    
            raise ValueError("A coupling map must be provided.")
        self._circuit = circuit
        self._coupling_map = coupling_map
        self._edge_links = np.array(self._coupling_map.get_edges(), dtype=np.int64)
        self._edge_links_num = self._edge_links.shape[0]
        self._node_num = self._coupling_map.size()
        self._iter = 0

        self.observation_space = gym.spaces.Box(
            low=-2, high=2, shape=(self._S_a, self._H), dtype=np.int32
        )

        self.action_space = gym.spaces.Discrete(self._S_a)
        return

    def action_masks(self) -> np.ndarray:
        candidate_num = len(self._swap_candidate)
        if candidate_num < self._S_a:
            return np.array(
                [True] * candidate_num + [False] * (self._S_a - candidate_num),
            )
        return np.array([True] * self._S_a)

    def set_level(self, level: int) -> None:
        if level < 1:
            raise ValueError("The level must be at least 3.")
        self._result_deque.clear()
        self._level = level

    def get_success_rate(self) -> float:
        """Calculate the success rate based on the results deque."""
        if len(self._result_deque) == 0:
            return 0.0
        return sum(self._result_deque) / len(self._result_deque)

    def get_level(self) -> int:
        """Get the current level of the environment."""
        return self._level

    def get_reset_failed(self) -> int:
        """Get the number of times the environment failed to reset."""
        return self._reset_failed

    def get_total_swap(self) -> int:
        """Get the total number of swaps performed."""
        return self._swap_number

    def front_layer_size(self) -> int:
        """Get the size of the front layer."""
        return len(self._front_layer)

    def render_sabre(self):
        """Render the SABRE DAG circuit."""
        return self._sabre_dag.draw()

    def render_original(self):
        """Render the original DAG circuit."""
        return self._dag.draw()

    def reset(
        self, *, seed: int | None = None, options: dict[str, Any] | None = None,
    ) -> tuple[np.ndarray, dict[str, Any]]:
        """Reset the environment to a new circuit and initialize the SABRE algorithm."""
        super().reset(seed=seed, options=options)
        self._swap_candidate = []
        self._success = False
        self._truncated = False
        self._swap_number = 0
        if self._iter == 0:
            self._init_sabre(self._circuit)
        else:
            self._circuit = self._circuit.inverse()
            self._repeat_sabre()


        _, Terminated = self._update_front_layer()
        self._reset_failed = 0
        return (
            self._unpack_state(Terminated),
            {},
        )

    def step(
        self, action: int
    ) -> tuple[np.ndarray, SupportsFloat, bool, bool, dict[str, Any]]:
        """Perform a step in the environment by applying a swap action."""
        isTruncated = self._apply_swap(action)
        executable_gate_number, isTerminated = self._update_front_layer()
        if isTruncated:
            self._result_deque.append(False)
        if isTerminated:
            self._result_deque.append(True)
        return (
            self._unpack_state(isTerminated),
            self.reward(
                executable_gate_number, self._swap_depth, isTerminated, isTruncated
            ),
            isTerminated,
            False,
            {},
        )

    def render(self):
        """Draw the destination DAG circuit."""
        return self._dest_dag.draw()

    def reward(
        self,
        executable_gate_number: int,
        swap_layer: int,
        isTerminated: bool,
        isTruncated: bool,
    ) -> float:
        """
        Calculate the reward based on the number of executable gates and swap layers.
        """
        return (
            -0.1
            + 0.2 * executable_gate_number
            - 0.05 * swap_layer
            + (5 if isTerminated else 0)
            - (10 if isTruncated else 0)
        )

    def _init_sabre(self, circuit: QuantumCircuit) -> None:
        # Set up Layout and Ancilla
        apply_ancilla_pass_manager = PassManager(
            [
                TrivialLayout(self._coupling_map),
                FullAncillaAllocation(self._coupling_map),
                EnlargeWithAncilla(),
                ApplyLayout(),
            ]
        )
        self._processed_circuit = apply_ancilla_pass_manager.run(circuit)
        self._dag = circuit_to_dag(self._processed_circuit)

        # Set up sabre dag (it contains only 2 qubit gates)
        self._sabre_dag = deepcopy(self._dag)
        self._sabre_dag.name = "sabre_swap"

        # Set up the result dag for check the result
        self._dest_dag = DAGCircuit()
        self._dest_dag.add_qreg(self._dag.qregs["q"])
        self._layout = Layout(
            {
                dagInNode.wire: pq._index
                for pq, dagInNode in self._dag.input_map.items()
                if isinstance(pq, Qubit)
            }
        )  # this is the mapping pi of the paper
        if len(self._dag.cregs) > 0:
            self._dest_dag.add_creg(
                self._dag.cregs["c"]
            )  # add classical register, since the layout only needs the qubit register, add creg after making the layout
        if self._random_layout:
            data = self._layout.get_virtual_bits()
            values = list(data.values())
            keys = list(data.keys())
            random.shuffle(values)
            self._layout = Layout(dict(zip(keys, values)))

        # Set up the initial state
        self._front_layer = self._sabre_dag.front_layer()
        self._swap_depth = 0
        return
    
    def _repeat_sabre(self) -> None:
        # Set up Layout and Ancilla
        apply_ancilla_pass_manager = PassManager(
            [
                TrivialLayout(self._coupling_map),
                FullAncillaAllocation(self._coupling_map),
                EnlargeWithAncilla(),
                ApplyLayout(),
                SetLayout(self._layout),
                ApplyLayout(),
            ]
        )
        self._processed_circuit = apply_ancilla_pass_manager.run(circuit)
        self._dag = circuit_to_dag(self._processed_circuit)

        # Set up sabre dag (it contains only 2 qubit gates)
        self._sabre_dag = deepcopy(self._dag)
        self._sabre_dag.name = "sabre_swap"

        # Set up the result dag for check the result
        self._dest_dag = DAGCircuit()
        self._dest_dag.add_qreg(self._dag.qregs["q"])
        self._layout = Layout(
            {
                dagInNode.wire: pq._index
                for pq, dagInNode in self._dag.input_map.items()
                if isinstance(pq, Qubit)
            }
        )  # this is the mapping pi of the paper
        if len(self._dag.cregs) > 0:
            self._dest_dag.add_creg(
                self._dag.cregs["c"]
            )  # add classical register, since the layout only needs the qubit register, add creg after making the layout

        # Set up the initial state
        self._front_layer = self._sabre_dag.front_layer()
        self._swap_depth = 0
        return

    def _update_front_layer(self) -> tuple[int, bool]:
        # update the front layer
        isTerminated = True
        executable_gate_number = 0
        while len(self._front_layer) > 0:
            execute_gate_list = []
            layout = self._layout.get_virtual_bits()

            # check if the node in the front layer can be executed
            for node in self._front_layer:
                q1, q2 = (
                    layout[node.qargs[0]],
                    layout[node.qargs[1]],
                )
                if self._coupling_map.distance(q1, q2) == 1:
                    executable_gate_number += 1
                    execute_gate_list.append(node)

            if len(execute_gate_list) != 0:
                self._swap_depth = 0
                # apply the executable gates
                for node in execute_gate_list:
                    self._sabre_dag.remove_op_node(node)
                    self._dest_dag.apply_operation_back(
                        node.op,
                        (
                            self._dest_dag.qregs["q"][layout[node.qargs[0]]],
                            self._dest_dag.qregs["q"][layout[node.qargs[1]]],
                        ),
                    )
                    self._front_layer = self._sabre_dag.front_layer()
            else:
                isTerminated = False
                break

        candidate = []
        if isTerminated:
            self._success = True
            return executable_gate_number, isTerminated

        for node in self._front_layer:
            layout = self._layout.get_virtual_bits()
            q1, q2 = (
                layout[node.qargs[0]],
                layout[node.qargs[1]],
            )
            for nq in self._coupling_map.neighbors(q1):
                candidate.append(frozenset([q1, nq]))
            for nq in self._coupling_map.neighbors(q2):
                candidate.append(frozenset([q2, nq]))
        self._swap_candidate = list(map(tuple, list(set(candidate))))

        return executable_gate_number, isTerminated

    def _apply_swap(self, action: int) -> bool:
        # Check if the action is valid
        if action >= len(self._swap_candidate):
            return True
        swap_action = self._swap_candidate[action]

        # apply the swap operation
        before_swap_depth = self._dest_dag.depth()
        self._dest_dag.apply_operation_back(
            self._swap_singleton,
            (
                self._dest_dag.qregs["q"][swap_action[0]],
                self._dest_dag.qregs["q"][swap_action[1]],
            ),
        )
        self._layout.swap(swap_action[0], swap_action[1])
        self._swap_depth += self._dest_dag.depth() - before_swap_depth
        self._swap_number += 1
        return False

    def _unpack_state(self, isTerminated: bool) -> np.ndarray:
        layers = self._sabre_dag.layers()
        current_layout = self._layout.get_virtual_bits()
        current_distances = []
        result_matrix = np.zeros(
            (self._S_a, self._H),
            dtype=np.int32,
        )
        if isTerminated:
            return result_matrix

        for i, layer in enumerate(layers):
            if i >= self._H:
                break
            current_distances.append(
                [
                    self._coupling_map.distance(
                        current_layout[node.qargs[0]], current_layout[node.qargs[1]]
                    )
                    for node in layer["graph"].op_nodes()
                ]
            )

        for i, (a, b) in enumerate(self._swap_candidate):
            if i >= self._S_a:
                break
            temp_layout = self._layout.copy()
            temp_layout.swap(a, b)
            temp_layout_map = temp_layout.get_virtual_bits()
            layers = self._sabre_dag.layers()
            for j, layer in enumerate(layers):
                if j >= self._H:
                    break
                new_distance = [
                    self._coupling_map.distance(
                        temp_layout_map[node.qargs[0]], temp_layout_map[node.qargs[1]]
                    )
                    for node in layer["graph"].op_nodes()
                ]
                result_matrix[i, j] = np.sum(
                    np.array(new_distance) - np.array(current_distances[j]),
                    dtype=np.int32,
                )

        return result_matrix

# %%
from sb3_contrib.ppo_mask import MaskablePPO

gym.register(id="SABRETest-v0", entry_point=SABRETestEnv) #type: ignore
env = gym.make("SABRETest-v0", circuit=layout_circuit, coupling_map=coupling_map)
model = MaskablePPO.load("./rl_model_1.zip")

def run_rl(env: gym.Env, model: MaskablePPO, episodes: int = 10):
    for episode in range(episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        i = 0
        while not done:
            i += 1
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, info = env.step(action)
            total_reward += float(reward)
        print(f"Episode {episode + 1}: Total Reward: {total_reward}, Steps: {i}")
    return dag_to_circuit(env.unwrapped._dest_dag)
# Out:
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\envs\registration.py:642: UserWarning: WARN: Overriding environment SABRETest-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
result_circuit_sb3=run_rl(env, model, episodes=31)
print("Number of gates in the original circuit:")
print(circuit.count_ops())
print("Number of gates in the SB3 circuit:")
print(result_circuit_sb3.count_ops())
print("Number of gates added by the sabre swap:")
print(result_circuit_sb3.size() - circuit.size())

# %%
result_circuit_sb3=run_rl(env, model, episodes=10)
print("Number of gates in the original circuit:")
print(circuit.count_ops())
print("Number of gates in the SB3 circuit:")
print(result_circuit_sb3.count_ops())
print("Number of gates added by the sabre swap:")
print(result_circuit_sb3.size() - circuit.size())
# Out:
# Episode 1: Total Reward: 6.05, Steps: 5
# Episode 2: Total Reward: 5.9, Steps: 3
# Episode 3: Total Reward: 5.9, Steps: 3
# Episode 4: Total Reward: 6.2, Steps: 4
# Episode 5: Total Reward: 6.05, Steps: 5
# Episode 6: Total Reward: 6.05, Steps: 5
# Episode 7: Total Reward: 6.2, Steps: 4
# Episode 8: Total Reward: 6.2, Steps: 4
# Episode 9: Total Reward: 5.7, Steps: 6
# Episode 10: Total Reward: 6.2, Steps: 4
# Number of gates in the original circuit:
# OrderedDict({'csx': 2, 'swap': 1, 'cx': 1, 'ecr': 1, 'cu3': 1, 'rzx': 1, 'rxx': 1})
# Number of gates in the SB3 circuit:
# OrderedDict({'swap': 5, 'csx': 2, 'ecr': 1, 'cx': 1, 'cu3': 1, 'rzx': 1, 'rxx': 1})
# Number of gates added by the sabre swap:
# 4
