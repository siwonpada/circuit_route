# %%
from qiskit.transpiler import CouplingMap


def create_Y(n) -> CouplingMap:
    """Create a Y-shaped coupling map with n qubits."""
    if not n % 2 == 0:
        raise ValueError("n must be odd for a Y-shaped coupling map.")
    result = CouplingMap().from_line(n - 1)
    result.add_physical_qubit(n - 1)
    result.add_edge(n - 1, n // 2)
    return result


def create_T(n) -> CouplingMap:
    """Create a T-shaped coupling map with n qubits."""
    result = CouplingMap().from_line(n - 1)
    result.add_physical_qubit(n - 1)
    result.add_edge(n - 1, n - 3)
    return result


coupling_map_list = [
    *[CouplingMap.from_line(n) for n in range(4, 11)],
    CouplingMap.from_ring(12),
    *[create_Y(2 * n) for n in range(2, 6)],
    *[create_T(n) for n in range(5, 11)],
    CouplingMap(
        [
            [0, 1],
            [1, 0],
            [1, 2],
            [1, 4],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 5],
            [4, 1],
            [4, 7],
            [5, 3],
            [5, 8],
            [6, 7],
            [7, 4],
            [7, 6],
            [7, 10],
            [8, 5],
            [8, 9],
            [8, 11],
            [9, 8],
            [10, 7],
            [10, 12],
            [11, 8],
            [11, 14],
            [12, 10],
            [12, 13],
            [12, 15],
            [13, 12],
            [13, 14],
            [14, 11],
            [14, 13],
            [14, 16],
            [15, 12],
            [15, 18],
            [16, 14],
            [16, 19],
            [17, 18],
            [18, 15],
            [18, 17],
            [18, 21],
            [19, 16],
            [19, 20],
            [19, 22],
            [20, 19],
            [21, 18],
            [21, 23],
            [22, 19],
            [22, 25],
            [23, 21],
            [23, 24],
            [24, 23],
            [24, 25],
            [25, 22],
            [25, 24],
            [25, 26],
            [26, 25],
        ]
    ),
    CouplingMap(
        [
            [0, 1],
            [1, 0],
            [1, 2],
            [1, 4],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 5],
            [3, 30],
            [4, 1],
            [4, 7],
            [5, 3],
            [5, 8],
            [6, 7],
            [7, 4],
            [7, 6],
            [7, 10],
            [8, 5],
            [8, 9],
            [8, 11],
            [9, 8],
            [10, 7],
            [10, 12],
            [11, 8],
            [11, 14],
            [12, 10],
            [12, 13],
            [12, 15],
            [13, 12],
            [13, 14],
            [14, 11],
            [14, 13],
            [14, 16],
            [15, 12],
            [15, 18],
            [16, 14],
            [16, 19],
            [17, 18],
            [18, 15],
            [18, 17],
            [18, 21],
            [19, 16],
            [19, 20],
            [19, 22],
            [20, 19],
            [21, 18],
            [21, 23],
            [22, 19],
            [22, 25],
            [23, 21],
            [23, 24],
            [23, 27],
            [24, 23],
            [24, 25],
            [25, 22],
            [25, 24],
            [25, 26],
            [26, 25],
            [27, 23],
            [27, 28],
            [28, 27],
            [28, 29],
            [29, 28],
            [30, 3],
            [30, 31],
            [31, 30],
            [31, 32],
            [32, 31],
        ]
    ),
    CouplingMap(
        [
            [0, 1],
            [0, 10],
            [1, 0],
            [1, 2],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 4],
            [4, 3],
            [4, 5],
            [4, 11],
            [5, 4],
            [5, 6],
            [6, 5],
            [6, 7],
            [7, 6],
            [7, 8],
            [8, 7],
            [8, 9],
            [8, 12],
            [9, 8],
            [10, 0],
            [10, 13],
            [11, 4],
            [11, 17],
            [12, 8],
            [12, 21],
            [13, 10],
            [13, 14],
            [14, 13],
            [14, 15],
            [15, 14],
            [15, 16],
            [15, 24],
            [16, 15],
            [16, 17],
            [17, 11],
            [17, 16],
            [17, 18],
            [18, 17],
            [18, 19],
            [19, 18],
            [19, 20],
            [19, 25],
            [20, 19],
            [20, 21],
            [21, 12],
            [21, 20],
            [21, 22],
            [22, 21],
            [22, 23],
            [23, 22],
            [23, 26],
            [24, 15],
            [24, 29],
            [25, 19],
            [25, 33],
            [26, 23],
            [26, 37],
            [27, 28],
            [27, 38],
            [28, 27],
            [28, 29],
            [29, 24],
            [29, 28],
            [29, 30],
            [30, 29],
            [30, 31],
            [31, 30],
            [31, 32],
            [31, 39],
            [32, 31],
            [32, 33],
            [33, 25],
            [33, 32],
            [33, 34],
            [34, 33],
            [34, 35],
            [35, 34],
            [35, 36],
            [35, 40],
            [36, 35],
            [36, 37],
            [37, 26],
            [37, 36],
            [38, 27],
            [38, 41],
            [39, 31],
            [39, 45],
            [40, 35],
            [40, 49],
            [41, 38],
            [41, 42],
            [42, 41],
            [42, 43],
            [43, 42],
            [43, 44],
            [43, 52],
            [44, 43],
            [44, 45],
            [45, 39],
            [45, 44],
            [45, 46],
            [46, 45],
            [46, 47],
            [47, 46],
            [47, 48],
            [47, 53],
            [48, 47],
            [48, 49],
            [49, 40],
            [49, 48],
            [49, 50],
            [50, 49],
            [50, 51],
            [51, 50],
            [51, 54],
            [52, 43],
            [52, 56],
            [53, 47],
            [53, 60],
            [54, 51],
            [54, 64],
            [55, 56],
            [56, 52],
            [56, 55],
            [56, 57],
            [57, 56],
            [57, 58],
            [58, 57],
            [58, 59],
            [59, 58],
            [59, 60],
            [60, 53],
            [60, 59],
            [60, 61],
            [61, 60],
            [61, 62],
            [62, 61],
            [62, 63],
            [63, 62],
            [63, 64],
            [64, 54],
            [64, 63],
        ]
    ),
    CouplingMap(
        [
            [0, 1],
            [0, 15],
            [1, 0],
            [1, 2],
            [2, 1],
            [2, 3],
            [3, 2],
            [3, 4],
            [4, 3],
            [4, 5],
            [4, 16],
            [5, 4],
            [5, 6],
            [6, 5],
            [6, 7],
            [7, 6],
            [7, 8],
            [8, 7],
            [8, 9],
            [8, 17],
            [9, 8],
            [9, 10],
            [10, 9],
            [10, 11],
            [11, 10],
            [11, 12],
            [12, 11],
            [12, 13],
            [12, 18],
            [13, 12],
            [13, 14],
            [14, 13],
            [15, 0],
            [15, 19],
            [16, 4],
            [16, 23],
            [17, 8],
            [17, 27],
            [18, 12],
            [18, 31],
            [19, 15],
            [19, 20],
            [20, 19],
            [20, 21],
            [21, 20],
            [21, 22],
            [21, 34],
            [22, 21],
            [22, 23],
            [23, 16],
            [23, 22],
            [23, 24],
            [24, 23],
            [24, 25],
            [25, 24],
            [25, 26],
            [25, 35],
            [26, 25],
            [26, 27],
            [27, 17],
            [27, 26],
            [27, 28],
            [28, 27],
            [28, 29],
            [29, 28],
            [29, 30],
            [29, 36],
            [30, 29],
            [30, 31],
            [31, 18],
            [31, 30],
            [31, 32],
            [32, 31],
            [32, 33],
            [33, 32],
            [33, 37],
            [34, 21],
            [34, 40],
            [35, 25],
            [35, 44],
            [36, 29],
            [36, 48],
            [37, 33],
            [37, 52],
            [38, 39],
            [38, 53],
            [39, 38],
            [39, 40],
            [40, 34],
            [40, 39],
            [40, 41],
            [41, 40],
            [41, 42],
            [42, 41],
            [42, 43],
            [42, 54],
            [43, 42],
            [43, 44],
            [44, 35],
            [44, 43],
            [44, 45],
            [45, 44],
            [45, 46],
            [46, 45],
            [46, 47],
            [46, 55],
            [47, 46],
            [47, 48],
            [48, 36],
            [48, 47],
            [48, 49],
            [49, 48],
            [49, 50],
            [50, 49],
            [50, 51],
            [50, 56],
            [51, 50],
            [51, 52],
            [52, 37],
            [52, 51],
            [53, 38],
            [53, 57],
            [54, 42],
            [54, 61],
            [55, 46],
            [55, 65],
            [56, 50],
            [56, 69],
            [57, 53],
            [57, 58],
            [58, 57],
            [58, 59],
            [59, 58],
            [59, 60],
            [59, 72],
            [60, 59],
            [60, 61],
            [61, 54],
            [61, 60],
            [61, 62],
            [62, 61],
            [62, 63],
            [63, 62],
            [63, 64],
            [63, 73],
            [64, 63],
            [64, 65],
            [65, 55],
            [65, 64],
            [65, 66],
            [66, 65],
            [66, 67],
            [67, 66],
            [67, 68],
            [67, 74],
            [68, 67],
            [68, 69],
            [69, 56],
            [69, 68],
            [69, 70],
            [70, 69],
            [70, 71],
            [71, 70],
            [71, 75],
            [72, 59],
            [72, 78],
            [73, 63],
            [73, 82],
            [74, 67],
            [74, 86],
            [75, 71],
            [75, 90],
            [76, 77],
            [76, 91],
            [77, 76],
            [77, 78],
            [78, 72],
            [78, 77],
            [78, 79],
            [79, 78],
            [79, 80],
            [80, 79],
            [80, 81],
            [80, 92],
            [81, 80],
            [81, 82],
            [82, 73],
            [82, 81],
            [82, 83],
            [83, 82],
            [83, 84],
            [84, 83],
            [84, 85],
            [84, 93],
            [85, 84],
            [85, 86],
            [86, 74],
            [86, 85],
            [86, 87],
            [87, 86],
            [87, 88],
            [88, 87],
            [88, 89],
            [88, 94],
            [89, 88],
            [89, 90],
            [90, 75],
            [90, 89],
            [91, 76],
            [91, 95],
            [92, 80],
            [92, 99],
            [93, 84],
            [93, 103],
            [94, 88],
            [94, 107],
            [95, 91],
            [95, 96],
            [96, 95],
            [96, 97],
            [97, 96],
            [97, 98],
            [97, 110],
            [98, 97],
            [98, 99],
            [99, 92],
            [99, 98],
            [99, 100],
            [100, 99],
            [100, 101],
            [101, 100],
            [101, 102],
            [101, 111],
            [102, 101],
            [102, 103],
            [103, 93],
            [103, 102],
            [103, 104],
            [104, 103],
            [104, 105],
            [105, 104],
            [105, 106],
            [105, 112],
            [106, 105],
            [106, 107],
            [107, 94],
            [107, 106],
            [107, 108],
            [108, 107],
            [108, 109],
            [109, 108],
            [109, 113],
            [110, 97],
            [110, 116],
            [111, 101],
            [111, 120],
            [112, 105],
            [112, 124],
            [113, 109],
            [113, 128],
            [114, 115],
            [114, 129],
            [115, 114],
            [115, 116],
            [116, 110],
            [116, 115],
            [116, 117],
            [117, 116],
            [117, 118],
            [118, 117],
            [118, 119],
            [118, 130],
            [119, 118],
            [119, 120],
            [120, 111],
            [120, 119],
            [120, 121],
            [121, 120],
            [121, 122],
            [122, 121],
            [122, 123],
            [122, 131],
            [123, 122],
            [123, 124],
            [124, 112],
            [124, 123],
            [124, 125],
            [125, 124],
            [125, 126],
            [126, 125],
            [126, 127],
            [126, 132],
            [127, 126],
            [127, 128],
            [128, 113],
            [128, 127],
            [129, 114],
            [130, 118],
            [131, 122],
            [132, 126],
        ]
    ),
]

# %%
from typing import Any, SupportsFloat
from copy import deepcopy
import gymnasium as gym
import numpy as np
import random

from qiskit import QuantumCircuit
from qiskit.circuit import Qubit
from qiskit.circuit.library.standard_gates import SwapGate
from qiskit.transpiler import CouplingMap, PassManager
from qiskit.transpiler.passes import (
    TrivialLayout,
    ApplyLayout,
    EnlargeWithAncilla,
    FullAncillaAllocation,
)
from qiskit.transpiler.layout import Layout
from qiskit.converters import circuit_to_dag
from qiskit.dagcircuit import DAGCircuit
from qiskit.circuit.random import random_circuit
from collections import deque

class CoRoutingEnv(gym.Env):
    def __init__(
        self,
        N: int = 10,
        start_level: int = 2,
        max_window_size: int = 100,
    ) -> None:
        self._N = N
        self._level = start_level
        self._swap_singleton = SwapGate()
        self._reset_failed = 0
        self._result_deque = deque(maxlen=max_window_size)

        self.observation_space = gym.spaces.Dict(
            {
                "nodes": gym.spaces.Box(
                    low=0,
                    high=self._N,
                    shape=(
                        133,
                        self._N,
                    ),
                    dtype=np.int32,
                ),
                "edge_links": gym.spaces.Box(low=0, high=132, shape=(300, 2)),
                "nodes_num": gym.spaces.Box(low=0, high=133, shape=(), dtype=np.int32),
            }
        )

        self.action_space = gym.spaces.MultiDiscrete(np.array([133, 133]))
        return

    def action_masks(self) -> np.ndarray:
        return np.array([True] * self._node_num + [False] * (133 - self._node_num))

    def set_level(self, level: int) -> None:
        if level < 1:
            raise ValueError("The level must be at least 3.")
        self._result_deque.clear()
        self._level = level

    def get_success_rate(self) -> float:
        """Calculate the success rate based on the results deque."""
        if len(self._result_deque) == 0:
            return 0.0
        return sum(self._result_deque) / len(self._result_deque)

    def get_level(self) -> int:
        """Get the current level of the environment."""
        return self._level

    def get_reset_failed(self) -> int:
        """Get the number of times the environment failed to reset."""
        return self._reset_failed

    def front_layer_size(self) -> int:
        """Get the size of the front layer."""
        return len(self._front_layer)

    def render_sabre(self):
        """Render the SABRE DAG circuit."""
        return self._sabre_dag.draw()

    def render_original(self):
        """Render the original DAG circuit."""
        return self._dag.draw()

    def reset(
        self, *, seed: int | None = None, options: dict[str, Any] | None = None
    ) -> tuple[dict, dict[str, Any]]:
        """Reset the environment to a new circuit and initialize the SABRE algorithm."""
        super().reset(seed=seed, options=options)
        self._coupling_map: CouplingMap = random.choice(coupling_map_list)
        self._edge_links = np.array(self._coupling_map.get_edges(), dtype=np.int64)
        self._node_num = self._coupling_map.size()
        self._success = False
        self._truncated = False
        Terminated = True
        i = 0
        while Terminated:
            i += 1
            if i % 1000 == 0:
                print("Resetting environment, attempt:", i)
            self._circuit = random_circuit(
                num_qubits=random.randint(
                    3,
                    min(self._level + 3, len(self._coupling_map.physical_qubits)),
                ),
                depth=self._level + 1,
                max_operands=2,
                measure=False,
                seed=seed,
                num_operand_distribution={1: 0, 2: 1},
            )
            self._init_sabre(self._circuit)
            _, Terminated = self._update_front_layer()
        self._reset_failed = i
        return (
            self._unpack_state(),
            {},
        )

    def step(
        self, action: tuple[int, int]
    ) -> tuple[dict, SupportsFloat, bool, bool, dict[str, Any]]:
        """Perform a step in the environment by applying a swap action."""
        isTruncated = self._apply_swap(action)
        executable_gate_number, isTerminated = self._update_front_layer()
        if isTruncated:
            self._result_deque.append(False)
        if isTerminated:
            self._result_deque.append(True)
        return (
            self._unpack_state(),
            self.reward(
                executable_gate_number, self._swap_depth, isTerminated, isTruncated
            ),
            isTerminated,
            False,
            {},
        )

    def render(self):
        """Draw the destination DAG circuit."""
        return self._dest_dag.draw()

    def reward(
        self,
        executable_gate_number: int,
        swap_layer: int,
        isTerminated: bool,
        isTruncated: bool,
    ) -> float:
        """
        Calculate the reward based on the number of executable gates and swap layers.
        """
        return (
            -0.1
            + 0.2 * executable_gate_number
            - 0.05 * swap_layer
            + (5 if isTerminated else 0)
            - (10 if isTruncated else 0)
        )

    def _init_sabre(self, circuit: QuantumCircuit) -> None:
        # Set up Layout and Ancilla
        apply_ancilla_pass_manager = PassManager(
            [
                TrivialLayout(self._coupling_map),
                FullAncillaAllocation(self._coupling_map),
                EnlargeWithAncilla(),
                ApplyLayout(),
            ]
        )
        self._processed_circuit = apply_ancilla_pass_manager.run(circuit)
        self._dag = circuit_to_dag(self._processed_circuit)

        # Set up sabre dag (it contains only 2 qubit gates)
        self._sabre_dag = deepcopy(self._dag)
        self._sabre_dag.name = "sabre_swap"

        # Set up the result dag for check the result
        self._dest_dag = DAGCircuit()
        self._dest_dag.add_qreg(self._dag.qregs["q"])
        self._layout = Layout(
            {
                dagInNode.wire: pq._index
                for pq, dagInNode in self._dag.input_map.items()
                if isinstance(pq, Qubit)
            }
        )  # this is the mapping pi of the paper
        if len(self._dag.cregs) > 0:
            self._dest_dag.add_creg(
                self._dag.cregs["c"]
            )  # add classical register, since the layout only needs the qubit register, add creg after making the layout

        # Set up the initial state
        self._front_layer = self._sabre_dag.front_layer()
        self._swap_depth = 0
        return

    def _update_front_layer(self) -> tuple[int, bool]:
        # update the front layer
        isTerminated = True
        executable_gate_number = 0
        while len(self._front_layer) > 0:
            execute_gate_list = []
            layout = self._layout.get_virtual_bits()

            # check if the node in the front layer can be executed
            for node in self._front_layer:
                q1, q2 = (
                    layout[node.qargs[0]],
                    layout[node.qargs[1]],
                )
                if self._coupling_map.distance(q1, q2) == 1:
                    executable_gate_number += 1
                    execute_gate_list.append(node)

            if len(execute_gate_list) != 0:
                self._swap_depth = 0
                # apply the executable gates
                for node in execute_gate_list:
                    self._sabre_dag.remove_op_node(node)
                    self._dest_dag.apply_operation_back(
                        node.op,
                        (
                            self._dest_dag.qregs["q"][layout[node.qargs[0]]],
                            self._dest_dag.qregs["q"][layout[node.qargs[1]]],
                        ),
                    )
                    self._front_layer = self._sabre_dag.front_layer()
            else:
                isTerminated = False
                break

        if isTerminated:
            self._success = True
            return executable_gate_number, isTerminated

        return executable_gate_number, isTerminated

    def _apply_swap(self, action: tuple[int, int]) -> bool:
        # Check if the action is valid
        if (
            action[0] >= self._node_num
            or action[1] >= self._node_num
            or self._coupling_map.distance(action[0], action[1]) != 1
        ):
            return True

        # apply the swap operation
        before_swap_depth = self._dest_dag.depth()
        self._dest_dag.apply_operation_back(
            self._swap_singleton,
            (
                self._dest_dag.qregs["q"][action[0]],
                self._dest_dag.qregs["q"][action[1]],
            ),
        )
        self._layout.swap(action[0], action[1])
        self._swap_depth += self._dest_dag.depth() - before_swap_depth
        return False

    def _unpack_state(self) -> dict:
        """Unpack the state into a Graph instance."""
        nodes = np.zeros((self._node_num, self._N), dtype=np.int32)
        layers = self._sabre_dag.layers()
        layout = self._layout.get_virtual_bits()
        counter = 0
        for i, layer in enumerate(layers):
            for node in layer["graph"].op_nodes():
                if counter >= self._N:
                    break
                nodes[layout[node.qargs[0]], counter] = i + 1
                nodes[layout[node.qargs[1]], counter] = i + 1
                counter += 1
        test = np.pad(
            nodes,
            ((0, 133 - nodes.shape[0]), (0, 0)),
            mode="constant",
            constant_values=0,
        )
        return {
            "nodes": test,
            "edge_links": np.pad(
                self._edge_links,
                ((0, 300 - self._edge_links.shape[0]), (0, 0)),
                mode="constant",
                constant_values=0,
            ),
            "nodes_num": self._node_num,
        }

# %%
from typing import Any
from typing import Dict

import gymnasium as gym
import os
import optuna
import numpy as np
import torch
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.data import Data, Batch

# %%
class GCNFeatureExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Dict, features_dim: int = 0) -> None:
        super().__init__(observation_space, features_dim)
        self.node_space = observation_space["nodes"].shape

        if self.node_space is None:
            raise ValueError("Observation space must contain 'nodes' with a valid shape.")
        
        self.gcn1 = GCNConv(self.node_space[1], 64)
        self.gcn2 = GCNConv(64, 32)
        self.gcn3 = GCNConv(32, 16)
        
        self.dropout = torch.nn.Dropout(0.1)

        self.feature_liner = torch.nn.Linear(16, features_dim)

    def forward(self, observations) -> torch.Tensor:
        batch_size = observations['nodes'].shape[0]
        device = observations['nodes'].device
        nodes_num = observations['nodes_num'].long()
        
        # 배치 내 각 그래프에 대해 Data 객체 생성
        data_list = []
        for i in range(batch_size):
            nodes = observations['nodes'][i].float()
            edge_index = observations['edge_links'][i].long()
            
            filtered_nodes = nodes[:nodes_num[i]]
            
            # 자기 자신과 연결되지 않은 엣지만 필터링
            edge_mask = edge_index[:, 0] != edge_index[:,1]
            filtered_edge_index = edge_index[edge_mask]
            
            # 빈 그래프 처리
            if filtered_nodes.size(0) == 0:
                # 빈 그래프인 경우 더미 노드 하나 생성
                filtered_nodes = torch.zeros((1, nodes.size(1)), device=device)
            
            if filtered_edge_index.size(1) == 0:
                # 빈 그래프인 경우 더미 엣지 하나 생성 (자기 자신과 연결)
                filtered_edge_index = torch.zeros((2, 1), dtype=torch.long, device=device)
            
            data = Data(x=filtered_nodes, edge_index=filtered_edge_index.T)
            data_list.append(data)
        
        # PyTorch Geometric의 배치 처리
        batch = Batch.from_data_list(data_list)

        if batch.batch.dtype != torch.long:
            batch.batch = batch.batch.long()
        
        # GCN 통과
        x = self.gcn1(batch.x, batch.edge_index)
        x = torch.relu(x)
        x = self.dropout(x)

        x = self.gcn2(x, batch.edge_index)
        x = torch.relu(x)
        x = self.dropout(x)

        x = self.gcn3(x, batch.edge_index)
        x = torch.relu(x)

        # Global mean pooling 적용
        graph_features = global_mean_pool(x, batch.batch)  # (batch_size, 16)

        # 선형 레이어를 통해 최종 특징 차원으로 변환
        graph_features = self.feature_liner(graph_features)  # (batch_size, features_dim
        
        return graph_features

# %%
ENV_ID = "CoRoutingEnv"

gym.register(id=ENV_ID, entry_point=CoRoutingEnv)

N_TRIALS = 2000
N_STARTUP_TRIALS = 10
N_EVALUATIONS = 5
N_TIMESTEPS = int(1e6)
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_EPISODES = 5

DEFAULT_HYPERPARAMS = {
    "policy": "MultiInputPolicy",
    "env": make_vec_env(ENV_ID, n_envs=2, env_kwargs={"start_level": 1}, vec_env_cls=SubprocVecEnv),
    "policy_kwargs": dict(
        features_extractor_class=GCNFeatureExtractor,
        features_extractor_kwargs=dict(features_dim=128),
    ),
}
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:328, in PipeConnection._recv_bytes(self, maxsize)
#     327 finally:
# --> 328     nread, err = ov.GetOverlappedResult(True)
#     329     if err == 0:
#
# BrokenPipeError: [WinError 109] 파이프가 끝났습니다
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 16
#      11 EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
#      12 N_EVAL_EPISODES = 5
#      14 DEFAULT_HYPERPARAMS = {
#      15     "policy": "MultiInputPolicy",
# ---> 16     "env": make_vec_env(ENV_ID, n_envs=2, env_kwargs={"start_level": 1}, vec_env_cls=SubprocVecEnv),
#      17     "policy_kwargs": dict(
#      18         features_extractor_class=GCNFeatureExtractor,
#      19         features_extractor_kwargs=dict(features_dim=128),
#      20     ),
#      21 }
#
# File d:\lab\circuit_route\.venv\Lib\site-packages\stable_baselines3\common\env_util.py:125, in make_vec_env(env_id, n_envs, seed, start_index, monitor_dir, wrapper_class, env_kwargs, vec_env_cls, vec_env_kwargs, monitor_kwargs, wrapper_kwargs)
#     121 if vec_env_cls is None:
#     122     # Default: use a DummyVecEnv
#     123     vec_env_cls = DummyVecEnv
# --> 125 vec_env = vec_env_cls([make_env(i + start_index) for i in range(n_envs)], **vec_env_kwargs)
#     126 # Prepare the seeds for the first reset
#     127 vec_env.seed(seed)
#
# File d:\lab\circuit_route\.venv\Lib\site-packages\stable_baselines3\common\vec_env\subproc_vec_env.py:127, in SubprocVecEnv.__init__(self, env_fns, start_method)
#     124     work_remote.close()
#     126 self.remotes[0].send(("get_spaces", None))
# --> 127 observation_space, action_space = self.remotes[0].recv()
#     129 super().__init__(len(env_fns), observation_space, action_space)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\connection.py:337, in PipeConnection._recv_bytes(self, maxsize)
#     335 except OSError as e:
#     336     if e.winerror == _winapi.ERROR_BROKEN_PIPE:
# --> 337         raise EOFError
#     338     else:
#     339         raise
#
# EOFError:

# %%
def sample_ppo_params(trial: optuna.Trial) -> Dict[str, Any]:
    """Sampler for PPO hyperparameters."""
    gamma: float = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    max_grad_norm: float = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
    gae_lambda: float = 1.0 - trial.suggest_float("gae_lambda", 0.001, 0.1, log=True)
    n_steps: int = 2 ** trial.suggest_int("exponent_n_steps", 3, 11)
    learning_rate: float = trial.suggest_float("lr", 1e-5, 1, log=True)
    ent_coef: float = trial.suggest_float("ent_coef", 0.0000001, 0.1, log=True)
    vf_coef: float = trial.suggest_float("vf_coef", 0.000001, 1.0, log=True)

    # Display true values.
    trial.set_user_attr("gamma_", gamma)
    trial.set_user_attr("gae_lambda_", gae_lambda)
    trial.set_user_attr("n_steps", n_steps)


    return {
        "n_steps": n_steps,
        "gamma": gamma,
        "gae_lambda": gae_lambda,
        "learning_rate": learning_rate,
        "ent_coef": ent_coef,
        "max_grad_norm": max_grad_norm,
        "vf_coef": vf_coef,
    }

# %%
from typing import Any

class CurriculumCallback(BaseCallback):
    def __init__(self, max_level: int = 1000, min_training_epi: int = 1000, success_threshold: float = 0.8, verbose: int = 0):
        super().__init__(verbose)
        self.max_level = max_level
        self.success_threshold = success_threshold
        self.min_training_epi = min_training_epi
        
        self.level = 1
        self.current_success_rate = 0.0
        self.log_freq = 100
        self.step_count = 0
        self.episode_count = 0

    def on_training_start(self, locals_: dict[str, Any], globals_: dict[str, Any]) -> None:
        super().on_training_start(locals_, globals_)
        self.training_env.env_method("set_level", level=self.level)

    def _on_step(self) -> bool:
        dones = self.locals.get("dones", [])
        
        if any(dones):
            for done in dones:
                if done:
                    self.episode_count += 1
            success_rate = np.mean(self.training_env.env_method("get_success_rate"))
            self.current_success_rate = success_rate
            
            if self.episode_count >= self.min_training_epi:
                if success_rate >= self.success_threshold:
                    self.episode_count = 0
                    self.level = min(self.level + 1, self.max_level)
                    self.training_env.env_method("set_level", level=self.level)
                    
                    if self.verbose > 0:
                        print(f"Level increased to {self.level} (success rate: {success_rate:.3f})")
        
        self.step_count += 1
        if self.step_count % self.log_freq == 0:
            self.logger.record("success_rate", self.current_success_rate)
            self.logger.record("level", self.level)
            
            if self.step_count % (self.log_freq * 5) == 0:
                front_layer_len = self.training_env.env_method("front_layer_size")
                reset_failed = self.training_env.env_method("get_reset_failed")
                
                self.logger.record("front_layer_size/mean", np.mean(front_layer_len))
                self.logger.record("reset_failed/mean", np.mean(reset_failed))
        
        return True

# %%
class TrialEvalCallback(EvalCallback):
    """Callback used for evaluating and reporting a trial."""

    def __init__(
        self,
        eval_env: gym.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        deterministic: bool = True,
        verbose: int = 0,
    ):
        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            train_level = self.training_env.env_method("get_level")
            self.eval_env.env_method("set_level", level=train_level[0])
            super()._on_step()
            self.eval_idx += 1
            self.trial.report(self.last_mean_reward, self.eval_idx)

            # Prune trial if need.
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True

# %%
def objective(trial: optuna.Trial) -> float:
    kwargs = DEFAULT_HYPERPARAMS.copy()
    # Sample hyperparameters.
    kwargs.update(sample_ppo_params(trial))
    # Create the RL model.
    model = PPO(**kwargs, tensorboard_log="./optuna_sb3_co/",verbose=1, device='cuda')
    # Create env used for evaluation.
    eval_env = Monitor(gym.make(ENV_ID, start_level=1))
    # Create the callback that will periodically evaluate and report the performance.
    eval_callback = TrialEvalCallback(
        eval_env, trial, n_eval_episodes=N_EVAL_EPISODES, eval_freq=EVAL_FREQ, deterministic=True
    )
    nan_encountered = False
    try:
        print("start learning")
        model.learn(N_TIMESTEPS, callback=[eval_callback, CurriculumCallback(verbose=1, success_threshold=0.9)])
        model.save(f"./optuna_sb3_co/saves/rl_model_{trial.number}")
        print("Learning end")
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN.
        print(e)
        nan_encountered = True
    finally:
        # Free memory.
        model.env.close()
        eval_env.close()

    # Tell the optimizer that the trial failed.
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward


sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
# Do not prune before 1/3 of the max budget is used.
pruner = MedianPruner(n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3)

if not os.path.exists("./optuna_sb3_co/study.db"):
    study = optuna.create_study(study_name="sb3_co",sampler=sampler, pruner=pruner, direction="maximize", storage="sqlite:///./optuna_sb3_co/study.db")
else:
    print("Loading existing study...")
    study = optuna.load_study(study_name="sb3_co", storage="sqlite:///./optuna_sb3_co/study.db")
try:
    study.optimize(objective, n_trials=N_TRIALS, timeout= 60 * 60 * 12)  # 12 hours
except KeyboardInterrupt:
    
    pass

print("Number of finished trials: ", len(study.trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

print("  User attrs:")
for key, value in trial.user_attrs.items():
    print("    {}: {}".format(key, value))
# Out:
# Loading existing study...
# Using cuda device
# start learning
# Logging to ./optuna_sb3_co/PPO_2
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\spaces\box.py:418: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# ----------------------------
# | time/              |     |
# |    fps             | 123 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 64  |
# ----------------------------
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# d:\lab\circuit_route\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 8.302741e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.78        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | 0.0169       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 3             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 192           |
# | train/                  |               |
# |    approx_kl            | 5.9697777e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0175        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 7.033348e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | 0.0172       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 5             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 320           |
# | train/                  |               |
# |    approx_kl            | 1.0036863e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0167        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 6             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 384           |
# | train/                  |               |
# |    approx_kl            | 9.0757385e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0171        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | level                   | 1             |
# | success_rate            | 0             |
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 7             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 448           |
# | train/                  |               |
# |    approx_kl            | 1.3200566e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 4.77e-07      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0162        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.0016       |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 8             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 512           |
# | train/                  |               |
# |    approx_kl            | 1.5245751e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0159        |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00173      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 576          |
# | train/                  |              |
# |    approx_kl            | 1.951307e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.78        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | 0.0153       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 2.123043e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.78        |
# |    explained_variance   | 0.000223     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | 0.0149       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 3.98e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 11            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 704           |
# | train/                  |               |
# |    approx_kl            | 2.1994114e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.01e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0157        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00174      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 12            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 3.2091513e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.19e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0134        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00278      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | success_rate            | 0            |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 13           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 832          |
# | train/                  |              |
# |    approx_kl            | 8.648913e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.78        |
# |    explained_variance   | 1.61e-06     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | 0.0107       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 14            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 896           |
# | train/                  |               |
# |    approx_kl            | 8.4511004e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 2.21e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0107        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00373      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 15            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 960           |
# | train/                  |               |
# |    approx_kl            | 0.00010261126 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 2.98e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00924       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00437      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 16            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 0.00011884514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 3.87e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00804       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00491      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 17            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 1088          |
# | train/                  |               |
# |    approx_kl            | 0.00011214428 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 4.89e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00899       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00453      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 18            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 0.00013986696 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 5.72e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00755       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00509      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | level                   | 1             |
# | success_rate            | 0             |
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 19            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 1216          |
# | train/                  |               |
# |    approx_kl            | 0.00017057732 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 7.33e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0055        |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00582      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 20            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 0.00017136056 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 8.82e-06      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00604       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00537      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 21            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 1344          |
# | train/                  |               |
# |    approx_kl            | 0.00017823838 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.03e-05      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.0063        |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00559      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 22            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 0.00020171981 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 0.000233      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.00426       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00641      |
# |    value_loss           | 3.91e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 23            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 1472          |
# | train/                  |               |
# |    approx_kl            | 0.00035003573 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 1.54e-05      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | 0.000519      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00795      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 24            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00056649745 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.78         |
# |    explained_variance   | 2.13e-05      |
# |    learning_rate        | 7.64e-05      |
# |    loss                 | -0.00343      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00935      |
# |    value_loss           | 4.06e+03      |
# -------------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | success_rate            | 0            |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 25           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 1600         |
# | train/                  |              |
# |    approx_kl            | 0.0011604484 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.77        |
# |    explained_variance   | 3.06e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.016       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 26           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0014634328 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.77        |
# |    explained_variance   | 4.21e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0224      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0177      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 27           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1728         |
# | train/                  |              |
# |    approx_kl            | 0.0018859794 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.76        |
# |    explained_variance   | 5.13e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0233      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0167      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 28           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0019831024 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.75        |
# |    explained_variance   | 6e-05        |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0299      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0202      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 29           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 1856         |
# | train/                  |              |
# |    approx_kl            | 0.0018061232 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.75        |
# |    explained_variance   | 6.86e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0289      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0194      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0023928694 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.74        |
# |    explained_variance   | 7.4e-05      |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0333      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.023       |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 31           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 1984         |
# | train/                  |              |
# |    approx_kl            | 0.0046520336 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.73        |
# |    explained_variance   | 8.41e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0522      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0292      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | front_layer_size/       |              |
# |    mean                 | 1            |
# | level                   | 1            |
# | reset_failed/           |              |
# |    mean                 | 1            |
# | success_rate            | 0            |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 32           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0030605877 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.72        |
# |    explained_variance   | 9.56e-05     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0385      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0235      |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 33           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 2112         |
# | train/                  |              |
# |    approx_kl            | 0.0052820025 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.7         |
# |    explained_variance   | 0.000109     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0594      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0337      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 34           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.0049785096 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.68        |
# |    explained_variance   | 0.000121     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0512      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.028       |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 35          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 2240        |
# | train/                  |             |
# |    approx_kl            | 0.004483884 |
# |    clip_fraction        | 0.00313     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.67       |
# |    explained_variance   | 0.000128    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0546     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0315     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 36          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.005852849 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.66       |
# |    explained_variance   | 0.000135    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0688     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 37           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 2368         |
# | train/                  |              |
# |    approx_kl            | 0.0057482515 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.65        |
# |    explained_variance   | 0.000145     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0711      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.039       |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | success_rate            | 0            |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 38           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 2432         |
# | train/                  |              |
# |    approx_kl            | 0.0049933484 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.63        |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0551      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0312      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 39           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 2496         |
# | train/                  |              |
# |    approx_kl            | 0.0040297722 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.61        |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0535      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0284      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 40          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.004512851 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.6        |
# |    explained_variance   | 0.000151    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0598     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0315     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 41           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 2624         |
# | train/                  |              |
# |    approx_kl            | 0.0053768354 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.59        |
# |    explained_variance   | 0.000154     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.063       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0346      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 42           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 2688         |
# | train/                  |              |
# |    approx_kl            | 0.0050741127 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.58        |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0607      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0339      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 43           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 2752         |
# | train/                  |              |
# |    approx_kl            | 0.0038169352 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.57        |
# |    explained_variance   | 0.000145     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0526      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0288      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | success_rate            | 0            |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 44           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0040824795 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.56        |
# |    explained_variance   | 0.000146     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0544      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0303      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 45          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 2880        |
# | train/                  |             |
# |    approx_kl            | 0.003073289 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.57       |
# |    explained_variance   | 0.000154    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0425     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 46          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 2944        |
# | train/                  |             |
# |    approx_kl            | 0.003392906 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.57       |
# |    explained_variance   | 0.000162    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0466     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 47           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 3008         |
# | train/                  |              |
# |    approx_kl            | 0.0033266423 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.57        |
# |    explained_variance   | 0.000168     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0529      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0301      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 48           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0021605156 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.57        |
# |    explained_variance   | 0.000536     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0312      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0199      |
# |    value_loss           | 3.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 49           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 3136         |
# | train/                  |              |
# |    approx_kl            | 0.0031255456 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.57        |
# |    explained_variance   | 0.000181     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0443      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0245      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ----------------------------------------
# | level                   | 1          |
# | success_rate            | 0          |
# | time/                   |            |
# |    fps                  | 108        |
# |    iterations           | 50         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 3200       |
# | train/                  |            |
# |    approx_kl            | 0.00279936 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.56      |
# |    explained_variance   | 0.000183   |
# |    learning_rate        | 7.64e-05   |
# |    loss                 | -0.0386    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0223    |
# |    value_loss           | 4.04e+03   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 51           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 3264         |
# | train/                  |              |
# |    approx_kl            | 0.0034666946 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.54        |
# |    explained_variance   | 0.000173     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0404      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0248      |
# |    value_loss           | 4.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 52           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0026371721 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.52        |
# |    explained_variance   | 0.000154     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0309      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0198      |
# |    value_loss           | 4.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 53          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3392        |
# | train/                  |             |
# |    approx_kl            | 0.002730107 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.51       |
# |    explained_variance   | 0.000141    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0429     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 54          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.003611412 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.5        |
# |    explained_variance   | 0.000137    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0486     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 55           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 3520         |
# | train/                  |              |
# |    approx_kl            | 0.0029371083 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.49        |
# |    explained_variance   | 0.000133     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0414      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0245      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 56           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0032083495 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.48        |
# |    explained_variance   | 0.000124     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0451      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0263      |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | level                   | 1           |
# | success_rate            | 0           |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 57          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 3648        |
# | train/                  |             |
# |    approx_kl            | 0.003270898 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.48       |
# |    explained_variance   | 0.000122    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0447     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 4.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 58           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 3712         |
# | train/                  |              |
# |    approx_kl            | 0.0037499154 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.48        |
# |    explained_variance   | 0.000121     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0497      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.028       |
# |    value_loss           | 4.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 59           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 3776         |
# | train/                  |              |
# |    approx_kl            | 0.0033201687 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.47        |
# |    explained_variance   | 0.000119     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.045       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0258      |
# |    value_loss           | 4.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 60           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0026314138 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.45        |
# |    explained_variance   | 0.000108     |
# |    learning_rate        | 7.64e-05     |
# ...
# |    entropy_loss         | -7.6         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0276      |
# |    n_updates            | 11390        |
# |    policy_gradient_loss | -0.0184      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1141         |
# |    time_elapsed         | 636          |
# |    total_timesteps      | 73024        |
# | train/                  |              |
# |    approx_kl            | 0.0011246549 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.6         |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0115      |
# |    n_updates            | 11400        |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1142         |
# |    time_elapsed         | 636          |
# |    total_timesteps      | 73088        |
# | train/                  |              |
# |    approx_kl            | 0.0015223548 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.61        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0179      |
# |    n_updates            | 11410        |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1143        |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 73152       |
# | train/                  |             |
# |    approx_kl            | 0.002346458 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0306     |
# |    n_updates            | 11420       |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | success_rate            | 0.0025       |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1144         |
# |    time_elapsed         | 637          |
# |    total_timesteps      | 73216        |
# | train/                  |              |
# |    approx_kl            | 0.0012003547 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.62        |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0138      |
# |    n_updates            | 11430        |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1145        |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 73280       |
# | train/                  |             |
# |    approx_kl            | 0.001140981 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0114     |
# |    n_updates            | 11440       |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1146         |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 73344        |
# | train/                  |              |
# |    approx_kl            | 0.0015265951 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.62        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0177      |
# |    n_updates            | 11450        |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1147        |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 73408       |
# | train/                  |             |
# |    approx_kl            | 0.001554559 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.017      |
# |    n_updates            | 11460       |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1148         |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 73472        |
# | train/                  |              |
# |    approx_kl            | 0.0012335898 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.63        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0132      |
# |    n_updates            | 11470        |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1149         |
# |    time_elapsed         | 640          |
# |    total_timesteps      | 73536        |
# | train/                  |              |
# |    approx_kl            | 0.0016554482 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.61        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0191      |
# |    n_updates            | 11480        |
# |    policy_gradient_loss | -0.0145      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | level                   | 1            |
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | success_rate            | 0.0025       |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1150         |
# |    time_elapsed         | 640          |
# |    total_timesteps      | 73600        |
# | train/                  |              |
# |    approx_kl            | 0.0018444918 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.6         |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0177      |
# |    n_updates            | 11490        |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1151        |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 73664       |
# | train/                  |             |
# |    approx_kl            | 0.002046748 |
# |    clip_fraction        | 0.00313     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.61       |
# |    explained_variance   | 0           |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0199     |
# |    n_updates            | 11500       |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1152         |
# |    time_elapsed         | 641          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0015977854 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.62        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.021       |
# |    n_updates            | 11510        |
# |    policy_gradient_loss | -0.0158      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1153        |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 73792       |
# | train/                  |             |
# |    approx_kl            | 0.001609738 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.64       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.0114     |
# |    n_updates            | 11520       |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1154         |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 73856        |
# | train/                  |              |
# |    approx_kl            | 0.0012644222 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.65        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0144      |
# |    n_updates            | 11530        |
# |    policy_gradient_loss | -0.0134      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1155         |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 73920        |
# | train/                  |              |
# |    approx_kl            | 0.0010581091 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.66        |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0133      |
# |    n_updates            | 11540        |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.1e+03      |
# |    ep_rew_mean          | -7.28e+04    |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 1156         |
# |    time_elapsed         | 644          |
# |    total_timesteps      | 73984        |
# | train/                  |              |
# |    approx_kl            | 0.0012984667 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.68        |
# |    explained_variance   | 0            |
# |    learning_rate        | 7.64e-05     |
# |    loss                 | -0.0134      |
# |    n_updates            | 11550        |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -----------------------------------------
# | front_layer_size/       |             |
# |    mean                 | 1.25        |
# | level                   | 1           |
# | reset_failed/           |             |
# |    mean                 | 1           |
# | rollout/                |             |
# |    ep_len_mean          | 7.1e+03     |
# |    ep_rew_mean          | -7.28e+04   |
# | success_rate            | 0.0025      |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 1157        |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 74048       |
# | train/                  |             |
# |    approx_kl            | 0.002075662 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 7.64e-05    |
# |    loss                 | -0.027      |
# |    n_updates            | 11560       |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
