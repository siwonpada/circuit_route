# %%
from qiskit.dagcircuit import DAGCircuit
import qiskit.qasm2
from qiskit.converters import circuit_to_dag

# %%
circuit = qiskit.qasm2.load('../data/4mod5-v0_19.qasm')

dag = circuit_to_dag(circuit)
dag.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2267x2012>

# %%
print(dag.two_qubit_ops())
# Out:
# [DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=1>, <Qubit register=(16, "q"), index=3>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=4>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=2>, <Qubit register=(16, "q"), index=3>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=4>, <Qubit register=(16, "q"), index=2>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=4>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=2>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=4>, <Qubit register=(16, "q"), index=2>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=4>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=2>, <Qubit register=(16, "q"), index=3>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=0>, <Qubit register=(16, "q"), index=3>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=4>, <Qubit register=(16, "q"), index=0>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=4>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=0>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=4>, <Qubit register=(16, "q"), index=0>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=3>, <Qubit register=(16, "q"), index=4>), cargs=()), DAGOpNode(op=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qargs=(<Qubit register=(16, "q"), index=0>, <Qubit register=(16, "q"), index=3>), cargs=())]

# %%
nodes = dag.op_nodes()

print(nodes[1].name, nodes[1].qargs, nodes[1].cargs)
for i in dag.op_predecessors(nodes[1]):
    print(i.name, i.qargs, i.cargs)
# Out:
# cx (<Qubit register=(16, "q"), index=1>, <Qubit register=(16, "q"), index=3>) ()
# x (<Qubit register=(16, "q"), index=3>,) ()

# %% [markdown]
# operation을 추가하는 방법은 단 두가지 있다. 앞에 하나를 추가하거나 뒤에 하나를 추가하거나 우리는 뒤에 하나를 추가하는 방법을 사용해야한다. [DAGCircuit.apply_operation_back](https://docs.quantum.ibm.com/api/qiskit/qiskit.dagcircuit.DAGCircuit#apply_operation_back)

# %%
from qiskit.circuit.library.standard_gates import SwapGate
qubits = dag.qubits
out =dag.output_map[qubits[0]]

dag.apply_operation_back(SwapGate(), [qubits[0], qubits[1]])


print(dag.output_map)
# Out:
# {<Qubit register=(16, "q"), index=0>: DAGOutNode(wire=<Qubit register=(16, "q"), index=0>), <Qubit register=(16, "q"), index=1>: DAGOutNode(wire=<Qubit register=(16, "q"), index=1>), <Qubit register=(16, "q"), index=2>: DAGOutNode(wire=<Qubit register=(16, "q"), index=2>), <Qubit register=(16, "q"), index=3>: DAGOutNode(wire=<Qubit register=(16, "q"), index=3>), <Qubit register=(16, "q"), index=4>: DAGOutNode(wire=<Qubit register=(16, "q"), index=4>), <Qubit register=(16, "q"), index=5>: DAGOutNode(wire=<Qubit register=(16, "q"), index=5>), <Qubit register=(16, "q"), index=6>: DAGOutNode(wire=<Qubit register=(16, "q"), index=6>), <Qubit register=(16, "q"), index=7>: DAGOutNode(wire=<Qubit register=(16, "q"), index=7>), <Qubit register=(16, "q"), index=8>: DAGOutNode(wire=<Qubit register=(16, "q"), index=8>), <Qubit register=(16, "q"), index=9>: DAGOutNode(wire=<Qubit register=(16, "q"), index=9>), <Qubit register=(16, "q"), index=10>: DAGOutNode(wire=<Qubit register=(16, "q"), index=10>), <Qubit register=(16, "q"), index=11>: DAGOutNode(wire=<Qubit register=(16, "q"), index=11>), <Qubit register=(16, "q"), index=12>: DAGOutNode(wire=<Qubit register=(16, "q"), index=12>), <Qubit register=(16, "q"), index=13>: DAGOutNode(wire=<Qubit register=(16, "q"), index=13>), <Qubit register=(16, "q"), index=14>: DAGOutNode(wire=<Qubit register=(16, "q"), index=14>), <Qubit register=(16, "q"), index=15>: DAGOutNode(wire=<Qubit register=(16, "q"), index=15>), <Clbit register=(16, "c"), index=0>: DAGOutNode(wire=<Clbit register=(16, "c"), index=0>), <Clbit register=(16, "c"), index=1>: DAGOutNode(wire=<Clbit register=(16, "c"), index=1>), <Clbit register=(16, "c"), index=2>: DAGOutNode(wire=<Clbit register=(16, "c"), index=2>), <Clbit register=(16, "c"), index=3>: DAGOutNode(wire=<Clbit register=(16, "c"), index=3>), <Clbit register=(16, "c"), index=4>: DAGOutNode(wire=<Clbit register=(16, "c"), index=4>), <Clbit register=(16, "c"), index=5>: DAGOutNode(wire=<Clbit register=(16, "c"), index=5>), <Clbit register=(16, "c"), index=6>: DAGOutNode(wire=<Clbit register=(16, "c"), index=6>), <Clbit register=(16, "c"), index=7>: DAGOutNode(wire=<Clbit register=(16, "c"), index=7>), <Clbit register=(16, "c"), index=8>: DAGOutNode(wire=<Clbit register=(16, "c"), index=8>), <Clbit register=(16, "c"), index=9>: DAGOutNode(wire=<Clbit register=(16, "c"), index=9>), <Clbit register=(16, "c"), index=10>: DAGOutNode(wire=<Clbit register=(16, "c"), index=10>), <Clbit register=(16, "c"), index=11>: DAGOutNode(wire=<Clbit register=(16, "c"), index=11>), <Clbit register=(16, "c"), index=12>: DAGOutNode(wire=<Clbit register=(16, "c"), index=12>), <Clbit register=(16, "c"), index=13>: DAGOutNode(wire=<Clbit register=(16, "c"), index=13>), <Clbit register=(16, "c"), index=14>: DAGOutNode(wire=<Clbit register=(16, "c"), index=14>), <Clbit register=(16, "c"), index=15>: DAGOutNode(wire=<Clbit register=(16, "c"), index=15>)}
